# %%
import numpy as np
import pandas as pd

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %%
# IRIS Plants Dataset
skdata = datasets.load_iris()

# Breast Cancer Dataset
# skdata = datasets.load_breast_cancer()

# Digits Dataset
# skdata = datasets.load_digits()

# Wine Dataset
# skdata = datasets.load_wine()

# Hayes-Roth Data Set: https://archive.ics.uci.edu/ml/datasets/Hayes-Roth
# df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/hayes-roth/hayes-roth.data', header=None)
# ndf = df.iloc[:, 1:] # Remove first column of user names
# x, y = ndf.iloc[:, :-1], np.array(ndf.iloc[:, -1]) # Split dataframe into data and target columns

# Standard Scaling
# x = StandardScaler().fit_transform(skdata.data)
# y = skdata.target

# MinMax Scaling
# x = MinMaxScaler().fit_transform(skdata.data)
# y = skdata.target

x = skdata.data
y = skdata.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=56)

print('Train Data - ', x_train.shape, y_train.shape)
print('Test Data  - ', x_test.shape, y_test.shape)
# Out:
# Train Data -  (105, 4) (105,)
# Test Data  -  (45, 4) (45,)

# %% [markdown]
# # Logistic Regression

# %%
# Train the Logistic Regression model
lr = LogisticRegression().fit(x_train, y_train)

# Predict test data
y_pred = lr.predict(x_test)

print('MSE      - ', mean_squared_error(y_test, y_pred))
print('Accuracy - ', accuracy_score(y_test, y_pred))
print()
print('Coefficients - ', lr.coef_)
print('Intercept    - ', lr.intercept_)
# Out:
# MSE      -  0.08888888888888889
# Accuracy -  0.9111111111111111
#
# Coefficients -  [[-0.4595491   0.84965249 -2.37234118 -0.95283241]
#  [ 0.53494946 -0.15710744 -0.23980267 -0.7487462 ]
#  [-0.07540036 -0.69254505  2.61214384  1.70157861]]
# Intercept    -  [  9.72291359   1.36675913 -11.08967273]

# %%
print('Test - ', y_test)
print('Pred - ', y_pred)
# Out:
# Test -  [2 1 1 2 2 2 2 0 0 2 1 0 0 0 1 0 0 0 2 1 0 2 1 1 0 2 2 1 1 1 2 2 1 0 0 0 2
#  2 2 0 1 2 2 1 1]
# Pred -  [2 1 2 2 2 2 2 0 0 2 1 0 0 0 2 0 0 0 2 1 0 2 1 1 0 2 2 1 1 1 2 2 2 0 0 0 2
#  2 2 0 1 2 2 2 1]
